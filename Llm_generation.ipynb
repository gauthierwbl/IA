# %% [markdown]
# ## 1) Installation des librairies

# %%
# !pip install langchain langchain-mistralai pydantic
# Out:
# Requirement already satisfied: langchain in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-mistralai in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: pydantic in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (2.12.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.1.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.55)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.3.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-mistralai) (0.4.3)
# Requirement already satisfied: tokenizers<1.0.0,>=0.15.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from langchain-mistralai) (0.22.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (1.1.7)
# Requirement already satisfied: filelock in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (0.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.5.0)
# Requirement already satisfied: colorama in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\gauthier\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0.0,>=0.15.1->langchain-mistralai) (8.3.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2) Définir la clé Mistral

# %%
import os

os.environ["MISTRAL_API_KEY"] = "KoMaytgiPsamEfcg4wDBPXN6dp20fYaC"

# %% [markdown]
# ## 3) Imports pour Mistral

# %%
from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from typing import List

# %% [markdown]
# ## 4) Schéma de sortie

# %%
class MusicRecommendation(BaseModel):
    genre: str = Field(description="Genre musical ciblé")
    summary: str = Field(description="Résumé global du style musical conseillé")
    key_characteristics: List[str] = Field(description="Caractéristiques audio clés")
    tempo_guideline: str = Field(description="Indication sur le tempo")
    mood: str = Field(description="Ambiance générale de la musique")

# %% [markdown]
# ## 5) Parser

# %%
parser = PydanticOutputParser(pydantic_object=MusicRecommendation)

# %% [markdown]
# ## 6) Prompt

# %%
prompt = PromptTemplate(
    template="""
Tu es un expert en production musicale et analyse de données Spotify.

Voici des paramètres audio optimaux obtenus par un modèle de machine learning
pour maximiser la popularité d'une musique.

Genre : {genre}

Paramètres audio :
{parameters}

À partir UNIQUEMENT de ces données, génère une recommandation musicale claire,
structurée et exploitable par un humain.

{format_instructions}
""",
    input_variables=["genre", "parameters"],
    partial_variables={
        "format_instructions": parser.get_format_instructions()
    },
)

# %% [markdown]
# ## 7) Initialiser Mistral

# %%
llm = ChatMistralAI(
    model="mistral-large-latest",
    temperature=0.3
)

# %%
import pandas as pd

top_pop_recipe = pd.read_csv(
    "top_pop_recipe.csv",
    index_col=0
).iloc[:, 0].to_dict()

top_pop_recipe
# Out:
# {'danceability': 0.6104664976343452,
#  'energy': 0.6607609583129278,
#  'loudness': -6.731318170523909,
#  'speechiness': 0.052192985404576,
#  'acousticness': 0.3500728041848407,
#  'instrumentalness': 0.002839068079716,
#  'liveness': 0.1598883663950482,
#  'valence': 0.4247178685179048,
#  'tempo': 110.97349793497328,
#  'duration_ms': 227589.59172928703}

# %% [markdown]
# ## 8) Appeler LLM

# %%
prompt_filled = prompt.format(
    genre="Pop",
    parameters=top_pop_recipe
)

raw_output = llm.invoke(prompt_filled)
recommendation = parser.parse(raw_output.content)

recommendation
# Out:
# MusicRecommendation(genre='Pop', summary="Une production pop moderne et équilibrée, conçue pour maximiser l'engagement et la popularité sur les plateformes de streaming. Ce style combine des éléments dansants, une énergie accessible et une touche d'authenticité acoustique pour créer un son à la fois actuel et intemporel. La structure est optimisée pour capter l'attention dès les premières secondes tout en maintenant une progression dynamique jusqu'à la fin.", key_characteristics=['Équilibre entre énergie et accessibilité : une danceability modérée (0.61) et une énergie marquée (0.66) pour un groove entraînant sans être agressif', 'Production soignée avec un volume maîtrisé (-6.73 dB) pour une écoute confortable sur tous les supports (casque, enceinte, voiture)', "Présence vocale dominante avec très peu d'éléments parlés (speechiness à 0.052) et quasi-absence d'instrumental (0.0028)", "Mélange subtil d'éléments électroniques et acoustiques (acousticness à 0.35) pour une touche organique sans sacrifier la modernité", 'Ambiance studio professionnelle avec une liveness faible (0.16) pour un son propre et contrôlé', "Durée optimale de 3 minutes et 47 secondes (227 590 ms) pour maintenir l'attention tout en respectant les algorithmes de streaming", 'Équilibre émotionnel modéré (valence à 0.42) : ni trop joyeux ni trop sombre, pour une large résonance auprès du public'], tempo_guideline="Tempo stable autour de 111 BPM (plage idéale : 108-114 BPM). Ce tempo modéré permet une danse légère tout en restant adapté aux formats radio et aux playlists 'chill' ou 'workout'. Pour varier, envisager des breaks rythmiques à 55 BPM (demi-temps) ou des accélérations ponctuelles jusqu'à 120 BPM en climax.", mood="Énergique mais chaleureux, avec une touche de nostalgie contemporaine. L'ambiance évoque une soirée entre amis, un road-trip ensoleillé ou une motivation positive. Le son est suffisamment universel pour s'adapter à des paroles variées (amour, empowerment, escapisme) tout en gardant une identité pop reconnaissable.")

# %% [markdown]
# ## 10) Nouveau schéma pour l'intention utilisateur

# %%
from pydantic import BaseModel, Field
from typing import List, Optional

class UserMusicIntent(BaseModel):
    """Ce que l'utilisateur veut en langage humain, mais structuré."""
    description: str = Field(description="Description brute fournie par l'utilisateur")
    genre: Optional[str] = Field(description="Genre musical souhaité (pop, rock, techno, etc.)", default=None)
    energy: Optional[str] = Field(description="Niveau d'énergie souhaité (faible, modérée, élevée)", default=None)
    mood: Optional[List[str]] = Field(description="Liste de mots décrivant l'ambiance (chill, joyeux, sombre, nostalgique...)", default=None)
    danceability: Optional[str] = Field(description="Niveau de côté dansant (faible, moyen, élevé)", default=None)
    tempo: Optional[str] = Field(description="Perception du tempo (lent, moyen, rapide)", default=None)
    duration_pref: Optional[str] = Field(description="Préférence de durée (court, moyen, long)", default=None)
    context: Optional[str] = Field(description="Contexte d'écoute (soirée, voiture, étude, sport, etc.)", default=None)

# %% [markdown]
# ## 10.1) Création d'un parser + prompt d'extraction d'intentions

# %%
from langchain_core.output_parsers import PydanticOutputParser
from langchain_core.prompts import PromptTemplate

intent_parser = PydanticOutputParser(pydantic_object=UserMusicIntent)

intent_prompt = PromptTemplate(
    template="""
Tu es un assistant qui analyse une demande de musique, écrite en français,
et tu dois en extraire des informations structurées.

Voici la demande de l'utilisateur :

\"\"\"{user_text}\"\"\"

Tu dois remplir les champs suivants :
- genre (si possible)
- energy (faible, modérée, élevée)
- mood (liste de mots)
- danceability (faible, moyenne, élevée)
- tempo (lent, moyen, rapide)
- duration_pref (court, moyen, long)
- context (par ex. soirée, voiture, travail, sport...)
- description (reprise ou reformulation du texte d'origine)

{format_instructions}
""",
    input_variables=["user_text"],
    partial_variables={
        "format_instructions": intent_parser.get_format_instructions()
    }
)

# %% [markdown]
# ## 10.2) Test avec un prompt utilisateur

# %%
user_text = """
Je veux une musique pop assez énergique, dansante, joyeuse,
pas trop longue, pour écouter en voiture l'été.
"""

intent_prompt_filled = intent_prompt.format(user_text=user_text)

raw_intent = llm.invoke(intent_prompt_filled)
print(raw_intent.content)

user_intent = intent_parser.parse(raw_intent.content)
user_intent
# Out:
# Voici le JSON structuré conforme à la demande de l'utilisateur :
#
# ```json
# {
#   "description": "Je veux une musique pop assez énergique, dansante, joyeuse, pas trop longue, pour écouter en voiture l'été.",
#   "genre": "pop",
#   "energy": "élevée",
#   "mood": ["joyeuse", "énergique", "estivale"],
#   "danceability": "élevée",
#   "tempo": "rapide",
#   "duration_pref": "court",
#   "context": "voiture"
# }
# ```
# UserMusicIntent(description="Je veux une musique pop assez énergique, dansante, joyeuse, pas trop longue, pour écouter en voiture l'été.", genre='pop', energy='élevée', mood=['joyeuse', 'énergique', 'estivale'], danceability='élevée', tempo='rapide', duration_pref='court', context='voiture')

# %% [markdown]
# ## 10.4) Traduire l'intention en paramètres

# %%
import numpy as np
import copy

def intent_to_audio_params(user_intent: UserMusicIntent, base_recipe: dict):
    """
    Prend une intention utilisateur + une recette de base (ex: top_pop_recipe)
    et renvoie un dictionnaire de paramètres audio ajustés.
    """
    params = copy.deepcopy(base_recipe)

    # 1) Energy → feature "energy"
    if user_intent.energy == "faible":
        params["energy"] = max(0.1, params["energy"] - 0.2)
    elif user_intent.energy == "élevée":
        params["energy"] = min(0.95, params["energy"] + 0.2)

    # 2) Danceability
    if user_intent.danceability == "faible":
        params["danceability"] = max(0.1, params["danceability"] - 0.2)
    elif user_intent.danceability == "élevée":
        params["danceability"] = min(0.95, params["danceability"] + 0.2)

    # 3) Tempo
    if user_intent.tempo == "lent":
        params["tempo"] = max(70, params["tempo"] - 20)
    elif user_intent.tempo == "rapide":
        params["tempo"] = min(140, params["tempo"] + 15)

    # 4) Valence (humeur globale)
    if user_intent.mood:
        if any(m in user_intent.mood for m in ["joyeux", "festif", "positif"]):
            params["valence"] = min(0.9, params.get("valence", 0.5) + 0.2)
        if any(m in user_intent.mood for m in ["sombre", "triste", "nostalgique"]):
            params["valence"] = max(0.1, params.get("valence", 0.5) - 0.2)

    # 5) Durée
    if user_intent.duration_pref == "court":
        params["duration_ms"] = 160_000  # ~2min40
    elif user_intent.duration_pref == "long":
        params["duration_ms"] = 260_000  # ~4min20

    # 6) Contexte "chill" → baisse un peu energy et tempo
    if user_intent.context and "chill" in user_intent.context:
        params["energy"] = max(0.1, params["energy"] - 0.1)
        params["tempo"] = max(80, params["tempo"] - 10)

    return params

# %% [markdown]
# ## 6) Générer une réponse en langage naturel

# %%
from pprint import pprint

pprint(audio_params_from_intent)
# Out:
# {'acousticness': 0.3500728041848407,
#  'danceability': 0.8104664976343452,
#  'duration_ms': 160000,
#  'energy': 0.8607609583129279,
#  'instrumentalness': 0.002839068079716,
#  'liveness': 0.1598883663950482,
#  'loudness': -6.731318170523909,
#  'speechiness': 0.052192985404576,
#  'tempo': 125.97349793497328,
#  'valence': 0.4247178685179048}

# %%
prompt_filled_for_user = prompt.format(
    genre=user_intent.genre or "Pop",
    parameters=audio_params_from_intent
)

raw_output_for_user = llm.invoke(prompt_filled_for_user)
personalized_reco = parser.parse(raw_output_for_user.content)
personalized_reco
# Out:
# MusicRecommendation(genre='pop', summary="Une production pop énergique et dansante, conçue pour maximiser l'engagement et la popularité sur les plateformes de streaming. Ce style combine des éléments modernes et accessibles, avec une touche d'authenticité acoustique pour équilibrer l'intensité électronique. Idéal pour les playlists virales et les moments de fête ou d'entraînement.", key_characteristics=['Rythme très dansant (danceability élevée) : structure rythmique claire et répétitive, idéale pour les mouvements et les chorégraphies', "Énergie élevée : instrumentation dynamique, percussions marquées et synthés puissants pour capter l'attention", 'Volume percutant (loudness à -6.73 dB) : mixage moderne et compétitif, sans saturation excessive', 'Présence vocale dominante (speechiness faible) : les paroles doivent être intelligibles et mélodiques, avec peu de passages parlés', "Équilibre acoustique (35% d'acousticness) : intégration subtile d'éléments organiques (guitares, pianos) pour adoucir l'électronique", "Absence quasi-totale d'instrumental (instrumentalness très faible) : priorité aux voix et aux mélodies vocales", 'Ambiance studio (liveness faible) : enregistrement contrôlé, sans réverbération excessive ni bruit de public', 'Valence modérée (42%) : tonalité légèrement positive mais pas naïve, avec une touche de mélancolie pour la profondeur émotionnelle', 'Durée optimale (2 min 40 sec) : format court pour maximiser les streams et les passages en radio/playlists'], tempo_guideline="Tempo précis de 126 BPM (plage optimale : 124-128 BPM). Ce rythme correspond à une marche rapide ou un jogging léger, idéal pour synchroniser les mouvements naturels du corps. À utiliser avec des croches régulières et des contretemps accentués pour renforcer l'effet dansant.", mood="Énergique et motivante, avec une touche de nostalgie ou de vulnérabilité pour créer un lien émotionnel. L'ambiance générale doit évoquer la joie de vivre, l'émancipation ou l'introspection positive, tout en restant accessible et universelle.")
